# %%
import pandas as pd

tabela = pd.read_excel('Produtos.xlsx')
display(tabela)
# Out:
#          Produtos  Preço Base Original     Tipo  Multiplicador Imposto  \
# 0          Tablet               999.99  Produto                    1.1
# 1   Pós Graduação              4500.00  Serviço                    1.3
# 2         Celular               899.99  Produto                    1.1
# 3  Passagem Aérea               799.00  Serviço                    1.3
# 4      Computador              3000.00  Produto                    1.1
# 5             SPA               480.48  Serviço                    1.3
# 6    Corte Cabelo                50.00  Serviço                    1.3
#
#    Preço Base Reais
# 0          1099.989
# 1          5850.000
# 2           989.989
# 3          1038.700
# 4          3300.000
# 5           624.624
# 6            65.000

# %%
#Atualizar o multiplicador
tabela.loc[tabela['Tipo']== 'Serviço', "Multiplicador Imposto"] = 1.5

# calcular multiplicador vezes o preço original
tabela["Preço Base Reais"] = tabela["Multiplicador Imposto"] * tabela["Preço Base Original"]

tabela.to_excel('Produtos Pandas.xlsx', index=False)

# %%
#importando
vendas_df = pd.read_csv(r'Contoso - Vendas  - 2017.csv', sep=';')
produtos_df = pd.read_csv(r'Contoso - Cadastro Produtos.csv', sep =';')
lojas_df = pd.read_csv(r'Contoso - Lojas.csv', sep =';')
clientes_df = pd.read_csv(r'Contoso - Clientes.csv', sep =';')

#Selecionando colunas
clientes_df = clientes_df[["ID Cliente", "E-mail"]]
produtos_df = produtos_df[["ID Produto", 'Categoria']]
lojas_df = lojas_df[['ID Loja', 'Nome da Loja']]

#mesclando e renomeando
vendas_df = vendas_df.merge(produtos_df, on='ID Produto')
vendas_df = vendas_df.merge(clientes_df, on="ID Cliente")
vendas_df = vendas_df.merge(lojas_df, on="ID Loja")

vendas_df = vendas_df.rename(columns={'E-mail': "E-mail Cliente"})

display(vendas_df)
# Out:
#         Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  \
# 0                     1    01/01/2017    02/01/2017         1       86
# 1                640549    28/08/2017    01/09/2017         4       86
# 2                102415    12/02/2017    13/02/2017         1       86
# 3                940800    16/12/2017    22/12/2017         6       86
# 4                715385    28/09/2017    28/09/2017         0       86
# ...                 ...           ...           ...       ...      ...
# 980637           766546    14/10/2017    14/10/2017         0       65
# 980638           540137    19/07/2017    20/07/2017         1       65
# 980639           864227    17/11/2017    17/11/2017         0       65
# 980640           553823    24/07/2017    25/07/2017         1       65
# 980641           508546    06/07/2017    10/07/2017         4       65
#
#         ID Produto  ID Promocao  ID Cliente  Quantidade Vendida  \
# ...

# %%
display(vendas_df.loc[vendas_df["ID Loja"] == 222])
# Out:
#         Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  \
# 949799           923369    10/12/2017    10/12/2017         0      222
# 949800             2554    02/01/2017    02/01/2017         0      222
# 949801           760764    13/10/2017    13/10/2017         0      222
# 949802           941024    17/12/2017    18/12/2017         1      222
# 949803           940499    16/12/2017    24/12/2017         8      222
# ...                 ...           ...           ...       ...      ...
# 950613           872909    21/11/2017    22/11/2017         1      222
# 950614           833615    06/11/2017    06/11/2017         0      222
# 950615           786455    21/10/2017    25/10/2017         4      222
# 950616           775333    17/10/2017    17/10/2017         0      222
# 950617           523991    12/07/2017    13/07/2017         1      222
#
#         ID Produto  ID Promocao  ID Cliente  Quantidade Vendida  \
# ...

# %%
from tqdm import tqdm

#Somar +1 na Quantidade Devolvida da loja de ID 222
#vendas_df.loc[vendas_df["ID Loja"] == 222, "Quantidade Devolvida"] += 


pbar = tqdm(total=len(vendas_df["ID Loja"]), position=0, leave=True)

for i, id_loja in enumerate(vendas_df["ID Loja"]):
    pbar.update()
    if id_loja == 222:
        vendas_df.loc[i, "Quantidade Devolvida"] += 1




display(vendas_df)
# Out:
# ...
#  90%|█████████ | 882704/980642 [00:00<00:00, 1546175.86it/s]
#         Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  \
# 0                     1    01/01/2017    02/01/2017         1       86
# 1                640549    28/08/2017    01/09/2017         4       86
# 2                102415    12/02/2017    13/02/2017         1       86
# 3                940800    16/12/2017    22/12/2017         6       86
# 4                715385    28/09/2017    28/09/2017         0       86
# ...                 ...           ...           ...       ...      ...
# 980637           766546    14/10/2017    14/10/2017         0       65
# 980638           540137    19/07/2017    20/07/2017         1       65
# 980639           864227    17/11/2017    17/11/2017         0       65
# 980640           553823    24/07/2017    25/07/2017         1       65
# 980641           508546    06/07/2017    10/07/2017         4       65
#
# ...
